# %%
a=5
print(id(a))
# Out:
# 140716274271480

# %%
b=5
print(id(b))
# Out:
# 140716274271480

# %%
a is b
# Out:
# True

# %%
name="maharaj"
"m" in name
# Out:
# True

# %%
"M" in  name
# Out:
# False

# %%
"maha" in  name
# Out:
# True

# %%
"Maha" in name
# Out:
# False
